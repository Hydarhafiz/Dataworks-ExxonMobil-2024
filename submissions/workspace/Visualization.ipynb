# %%
import pandas as pd
from pandas import DataFrame
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import numpy as np

# %%
Resevoir0StateTrainDataset = pd.read_csv(r"C:\Users\hydar\Downloads\student_starter_pack\dataset\training\Reservoir0\state.csv")
display(Resevoir0StateTrainDataset)
# Out:
#               X           Y    Depth     PERMX     PERMY    PERMZ    PORO  \
# 0     552292.00  6798283.88 -8197.92   12.0660   12.0660   0.5428  0.1156
# 1     552720.14  6798277.25 -8191.53  161.8341  161.8341   4.7231  0.1783
# 2     553148.33  6798270.75 -8186.99  141.0474  141.0474   4.2118  0.1750
# 3     553576.81  6798264.63 -8184.66  401.8454  401.8454  10.0782  0.2002
# 4     554005.80  6798259.13 -8182.89  797.1256  797.1256  17.8350  0.2168
# ...         ...         ...      ...       ...       ...      ...     ...
# 5178  556171.53  6809225.50 -8439.60  199.4984  199.4984   5.6228  0.1833
# 5179  556568.33  6809226.75 -8474.44  302.8445  302.8445   7.9619  0.1934
# 5180  557006.72  6809221.50 -8508.94  227.3471  227.3471   6.2696  0.1865
# 5181  557457.34  6809215.88 -8531.53  306.7809  306.7809   8.0480  0.1937
# 5182  557906.11  6809210.88 -8592.51    0.2467    0.2467   0.0212  0.0218
#
#       Transmissibility
# 0                    1
# 1                    1
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = Resevoir0StateTrainDataset['X']
y = Resevoir0StateTrainDataset['Y']
depth = Resevoir0StateTrainDataset['Depth']

x_first_50 = x[:50]
y_first_50 = y[:50]
depth_first_50 = depth[:50]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
ax.scatter(x_first_50, y_first_50, depth_first_50, c='blue', marker='o')

# %%
# Show the plot
plt.show()

# %%
import plotly.express as px

# %%
# Create a 3D scatter plot
fig = px.scatter_3d(Resevoir0StateTrainDataset, x='X', y='Y', z='Depth', color='PERMX', title='3D Plot of X, Y, and Depth')

# Customize axes labels
fig.update_layout(scene = dict(
                    xaxis_title='X',
                    yaxis_title='Y',
                    zaxis_title='Depth'))

# Show the plot
fig.show()
